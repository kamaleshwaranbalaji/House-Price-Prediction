# %%
import warnings
warnings.filterwarnings('ignore')

# %%
#import the required libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
import seaborn as sns

# %%
#read the data in a dataframe

# %%
data = pd.read_csv('Housing (1).csv')
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#make a copy of the original data set
df = data.copy()
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        3      yes        no       no
# 1  12250000  8960         4          4        4      yes        no       no
# 2  12250000  9960         3          2        2      yes        no      yes
# 3  12215000  7500         4          2        2      yes        no      yes
# 4  11410000  7420         4          1        2      yes       yes      yes
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0              no             yes        2      yes        furnished
# 1              no             yes        3       no        furnished
# 2              no              no        2      yes   semi-furnished
# 3              no             yes        3      yes        furnished
# 4              no             yes        2       no        furnished

# %%
#convert the string values to numerical so that the ML model can be trained

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['mainroad'] = le.fit_transform(df['mainroad'])
df['guestroom'] = le.fit_transform(df['guestroom'])
df['basement'] = le.fit_transform(df['basement'])
df['hotwaterheating'] = le.fit_transform(df['hotwaterheating'])
df['airconditioning'] = le.fit_transform(df['airconditioning'])
df['prefarea'] = le.fit_transform(df['prefarea'])
df['furnishingstatus'] = le.fit_transform(df['furnishingstatus'])

# %%
df.head()
# Out:
#       price  area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000  7420         4          2        3         1          0
# 1  12250000  8960         4          4        4         1          0
# 2  12250000  9960         3          2        2         1          0
# 3  12215000  7500         4          2        2         1          0
# 4  11410000  7420         4          1        2         1          1
#
#    basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0         0                0                1        2         1
# 1         0                0                1        3         0
# 2         1                0                0        2         1
# 3         1                0                1        3         1
# 4         1                0                1        2         0
#
#    furnishingstatus
# 0                 0
# 1                 0
# 2                 1
# 3                 0
# 4                 0

# %%
X = df.drop(['price'],axis =1)
#0 is for rows , 1 is for columns
y = df.price

# %%
X
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 0    7420         4          2        3         1          0         0
# 1    8960         4          4        4         1          0         0
# 2    9960         3          2        2         1          0         1
# 3    7500         4          2        2         1          0         1
# 4    7420         4          1        2         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 540  3000         2          1        1         1          0         1
# 541  2400         3          1        1         0          0         0
# 542  3620         2          1        1         1          0         0
# 543  2910         3          1        1         0          0         0
# 544  3850         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
#spliting the data in train and test datasets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X,y, test_size=0.2, random_state =11)

# %%
X_train.shape
# Out:
# (436, 12)

# %%
X_test.shape
# Out:
# (109, 12)

# %%
545*0.2
#20 percent is taken as the test_set(that is the test size=0.2)
# Out:
# 109.0

# %%
#create a linear regression model

# %%
model=linear_model.LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('R2 score is: ', model.score(X_train,y_train))
# Out:
# R2 score is:  0.6887894702113726

# %%
from sklearn.tree import DecisionTreeRegressor
model1 = DecisionTreeRegressor()

# %%
model1.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
print('R2 score is: ', model1.score(X_train,y_train))
# Out:
# R2 score is:  0.9987526580712995

# %%
from sklearn.ensemble import RandomForestRegressor
model2 = RandomForestRegressor()
model2.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
print('R2 score is: ', model2.score(X_train,y_train))
# Out:
# R2 score is:  0.9436718634328117

# %%
predictions2 = model2.predict(X_train)
predictions2 = np.round(predictions,1)
print(predictions2)
# Out:
# [ 5691265.5  4275967.5  5847763.7  5693801.   4794494.9  3105889.2
#   7500065.9  5452773.5  5741271.   6530777.3  6662873.1  6542742.8
#   4049946.8  4889520.2  4167069.9  2444642.2  5219290.2  5736726.7
#   6877444.1  4825367.9  4764737.9  3315567.1  3550205.5  3960506.3
#   2931999.9  5502403.4  3287374.6  4092258.2  5377284.9  6629446.1
#   6755610.   3708001.9  5900908.1  4636968.   2544188.   6729531.1
#   6141470.2  4162904.8  4269326.7  3895892.6  3976284.8  3966165.2
#   7058574.1  6458455.   6671932.6  5276267.4  4467512.8  5981934.6
#   8289823.7  3879972.9  4527219.4  4875002.9  4563416.5  6433703.2
#   3405609.9  6724885.   2788160.3  6373233.   4268945.4  6719488.8
#   4701092.8  2241161.7  4454282.5  3755009.6  4349803.6  5112183.3
#   6436189.8  4139739.8  4887314.3  5914409.1  2857448.9  7834817.
#   3773093.   5810984.   4984442.7  5487926.3  5714572.2  4210528.4
#   4921690.   4413398.6  4426538.9  3078529.1  4109017.6  3220813.
# ...

# %%
X_train['Actuals']=y_train
X_train['Pred']= predictions2
X_train
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 123  7320         4          2        2         1          0         0
# 294  4000         4          2        2         0          0         0
# 296  4600         3          2        2         1          0         0
# 169  6540         4          2        2         0          0         0
# 216  6040         3          1        1         1          0         0
# ..    ...       ...        ...      ...       ...        ...       ...
# 332  5500         4          1        2         1          1         1
# 269  3900         3          1        2         1          0         0
# 337  2145         4          2        1         1          0         1
# 91   6750         2          1        1         1          1         1
# 80   6000         3          1        2         1          0         0
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus  \
# ...

# %%
pred_test = model2.predict(X_test)
pred_test = np.round(pred_test,1)

# %%
X_test['Actuals'] = y_test
X_test['Pred'] = pred_test
X_test
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 136  5400         4          2        2         1          0         0
# 184  3000         3          2        2         1          1         1
# 375  5960         3          1        2         1          1         1
# 70   4000         3          2        2         1          0         1
# 104  5500         3          2        1         1          1         1
# ..    ...       ...        ...      ...       ...        ...       ...
# 341  3180         2          2        1         1          0         1
# 444  3120         3          1        2         0          0         0
# 366  3630         2          1        1         1          0         1
# 485  3630         2          1        1         1          0         0
# 26   6000         3          2        4         1          1         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus  \
# ...

# %%
#merge the train and test dataset
data_pred = X_train.append(X_test)
data_pred
# Out:
#      area  bedrooms  bathrooms  stories  mainroad  guestroom  basement  \
# 123  7320         4          2        2         1          0         0
# 294  4000         4          2        2         0          0         0
# 296  4600         3          2        2         1          0         0
# 169  6540         4          2        2         0          0         0
# 216  6040         3          1        1         1          0         0
# ..    ...       ...        ...      ...       ...        ...       ...
# 341  3180         2          2        1         1          0         1
# 444  3120         3          1        2         0          0         0
# 366  3630         2          1        1         1          0         1
# 485  3630         2          1        1         1          0         0
# 26   6000         3          2        4         1          1         1
#
#      hotwaterheating  airconditioning  parking  prefarea  furnishingstatus  \
# ...

# %%
data_pred.shape
# Out:
# (545, 14)

# %%
#order and label encoded

# %%
data_complete =pd.merge(data,data_pred, how ='inner', left_on=['area', 'price'], right_on=['area', 'Actuals'])
data_complete
# Out:
#         price  area  bedrooms_x  bathrooms_x  stories_x mainroad_x  \
# 0    13300000  7420           4            2          3        yes
# 1    12250000  8960           4            4          4        yes
# 2    12250000  9960           3            2          2        yes
# 3    12215000  7500           4            2          2        yes
# 4    11410000  7420           4            1          2        yes
# ..        ...   ...         ...          ...        ...        ...
# 568   1820000  3000           2            1          1        yes
# 569   1767150  2400           3            1          1         no
# 570   1750000  3620           2            1          1        yes
# 571   1750000  2910           3            1          1         no
# 572   1750000  3850           3            1          2        yes
#
#     guestroom_x basement_x hotwaterheating_x airconditioning_x  ...  \
# 0            no         no                no               yes  ...
# ...

# %%
data_complete.to_csv('housing_dataset (dr2).csv')

# %%
feature_columns = ['bedrooms_y', 'bathrooms_y', 'stories_y', 'mainroad_y', 'guestroom_y', 
                   'basement_y', 'hotwaterheating_y', 'airconditioning_y',
                   'parking_y', 'prefarea_y', 'furnishingstatus_y', 'Actuals']
data_complete.drop(feature_columns, axis =1, inplace = True)

# %%
data_complete
# Out:
#         price  area  bedrooms_x  bathrooms_x  stories_x mainroad_x  \
# 0    13300000  7420           4            2          3        yes
# 1    12250000  8960           4            4          4        yes
# 2    12250000  9960           3            2          2        yes
# 3    12215000  7500           4            2          2        yes
# 4    11410000  7420           4            1          2        yes
# ..        ...   ...         ...          ...        ...        ...
# 568   1820000  3000           2            1          1        yes
# 569   1767150  2400           3            1          1         no
# 570   1750000  3620           2            1          1        yes
# 571   1750000  2910           3            1          1         no
# 572   1750000  3850           3            1          2        yes
#
#     guestroom_x basement_x hotwaterheating_x airconditioning_x  parking_x  \
# 0            no         no                no               yes          2
# ...

# %%
#rename the columns
rename_dict ={
    'bedrooms_x' : 'bedrooms', 
    'bathrooms_x' : 'bathrooms',
    'stories_x'  : 'stories',
    'mainroad_x': 'mainroad',
    'guestroom_x' : 'guestroom',
    'basement_x' : 'basement',
    'hotwaterheating_x' : 'hotwaterheating',
    'airconditioning_x' : 'airconditioning',
    'parking_x' : 'parking', 
    'prefarea_x': 'prefarea',
    'furnishingstatus_x' : 'furnishingstatus'}

data_complete.rename(columns=rename_dict, inplace=True)

# %%
data_complete
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 568   1820000  3000         2          1        1      yes        no      yes
# 569   1767150  2400         3          1        1       no        no       no
# 570   1750000  3620         2          1        1      yes        no       no
# 571   1750000  2910         3          1        1       no        no       no
# 572   1750000  3850         3          1        2      yes        no       no
#
# ...
